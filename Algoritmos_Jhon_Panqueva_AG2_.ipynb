# %% [markdown]
# #Actividad Guiada 2
# ## Jhon Panqueva
#
# https://github.com/jpanqueva/03MIAR_04_A_2023-24_Algoritmos-de-Optimizacion

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
f = lambda X:X[0]**2 + X[1]**2
df = lambda X:[2*X[0],2*X[1]]

resolucion = 20
rango = 2.5
X=np.linspace(-rango,rango,resolucion)
Y=np.linspace(-rango,rango,resolucion)
Z=np.zeros((resolucion,resolucion))

for ix,x in enumerate(X):
  for iy, y in enumerate(Y):
    Z[ix,iy] = f([x,y])

contour = plt.contourf(X,Y,Z,resolucion)
cbar = plt.colorbar(contour)

#generamos el punto de partida
P=[random.uniform(-rango,rango),random.uniform(-rango,rango)]

plt.plot(P[0],P[1],"o", c="red")
TA = 0.05

for _ in range(500):
  grad = df(P)
  P[0], P[1] = P[0]-TA*grad[0],P[1] - TA*grad[1]
  plt.plot(P[0],P[1],"o",c="red")

plt.plot(P[0],P[1],"o",c="white")
print("Solucion: ", P,f(P))
# Out:
# Solucion:  [2.9854241271228844e-23, 1.869664520671965e-23] 1.2408402638666965e-45
